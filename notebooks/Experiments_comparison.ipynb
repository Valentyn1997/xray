# %%
import mlflow
import pandas as pd
import numpy as np
MLFLOW_TRACKING_URI = 'http://localhost:5001'
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
summary = {}

# %%
cae = mlflow.search_runs(experiment_ids=16)
cae = pd.merge(cae.groupby(by='tags.mlflow.parentRunId').agg(['mean', 'std']), cae, 
         left_on='tags.mlflow.parentRunId', right_on='run_id')
cae['model'] = 'cae'
summary['cae'] = (cae.filter(regex=r"\('metrics\.(roc-auc).+(mean|std)'\)|params.data_source|params.pipeline|model"))
summary['cae']
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py:617: UserWarning: merging between different levels can give an unintended result (2 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)
#    (metrics.roc-auc_mse, mean)  (metrics.roc-auc_mse, std)  \
# 0                     0.465710                    0.022399
# 1                     0.509988                    0.021172
# 2                     0.503871                    0.033538
# 3                     0.570020                    0.018518
# 4                     0.459825                    0.033185
# 5                     0.500570                    0.013251
#
#    (metrics.roc-auc_mse_top_k, mean)  (metrics.roc-auc_mse_top_k, std)  \
# 0                           0.485882                          0.015268
# 1                           0.473119                          0.018063
# 2                           0.448313                          0.025102
# 3                           0.553448                          0.022759
# 4                           0.465520                          0.013184
# 5                           0.505736                          0.039243
#
#                                      params.pipeline params.data_source model
# 0  {'hist_equalisation': False, 'otsu_filter': Fa...    XR_HAND_CROPPED   cae
# 1  {'hist_equalisation': True, 'otsu_filter': Fal...    XR_HAND_CROPPED   cae
# 2  {'hist_equalisation': True, 'otsu_filter': Fal...            XR_HAND   cae
# 3  {'hist_equalisation': True, 'otsu_filter': Fal...  XR_HAND_PHOTOSHOP   cae
# 4  {'hist_equalisation': False, 'otsu_filter': Fa...            XR_HAND   cae
# 5  {'hist_equalisation': False, 'otsu_filter': Fa...  XR_HAND_PHOTOSHOP   cae

# %%
bae = mlflow.search_runs(experiment_ids=11)
bae = pd.merge(bae.groupby(by='tags.mlflow.parentRunId').agg(['mean', 'std']), bae, 
         left_on='tags.mlflow.parentRunId', right_on='run_id')
bae['model'] = 'bae'
summary['bae'] = (bae.filter(regex=r"\('metrics\.(roc-auc).+(mean|std)'\)|params.data_source|params.pipeline|model"))
summary['bae']
# Out:
#    (metrics.roc-auc_mse, mean)  (metrics.roc-auc_mse, std)  \
# 0                     0.506337                    0.008440
# 1                     0.461895                    0.019300
# 2                     0.559903                    0.025620
# 3                     0.472851                    0.017869
# 4                     0.480214                    0.014175
# 5                     0.460651                    0.020063
#
#    (metrics.roc-auc_mse_top_k, mean)  (metrics.roc-auc_mse_top_k, std)  \
# 0                           0.454385                          0.012550
# 1                           0.441044                          0.010932
# 2                           0.516216                          0.019336
# 3                           0.455072                          0.016610
# 4                           0.451329                          0.009417
# 5                           0.445508                          0.012705
#
#                                      params.pipeline params.data_source model
# 0  {'hist_equalisation': False, 'otsu_filter': Fa...  XR_HAND_PHOTOSHOP   bae
# 1  {'hist_equalisation': False, 'otsu_filter': Fa...            XR_HAND   bae
# 2  {'hist_equalisation': True, 'otsu_filter': Fal...  XR_HAND_PHOTOSHOP   bae
# 3  {'hist_equalisation': True, 'otsu_filter': Fal...            XR_HAND   bae
# 4  {'hist_equalisation': True, 'otsu_filter': Fal...    XR_HAND_CROPPED   bae
# 5  {'hist_equalisation': False, 'otsu_filter': Fa...    XR_HAND_CROPPED   bae

# %%
vae = mlflow.search_runs(experiment_ids=17)
vae = pd.merge(vae.groupby(by='tags.mlflow.parentRunId').agg(['mean', 'std']), vae, 
         left_on='tags.mlflow.parentRunId', right_on='run_id')
vae['model'] = 'vae'
summary['vae'] = (vae.filter(regex=r"\('metrics\.(roc-auc).+(mean|std)'\)|params.data_source|params.pipeline|model"))
summary['vae']
# Out:
#    (metrics.roc-auc_l1, mean)  (metrics.roc-auc_l1, std)  \
# 0                    0.432151                   0.033076
# 1                    0.435117                   0.013975
# 2                    0.438137                   0.033452
# 3                    0.437759                   0.016311
# 4                    0.445974                   0.015792
# 5                    0.482800                   0.009075
#
#    (metrics.roc-auc_kld, mean)  (metrics.roc-auc_kld, std)  \
# 0                     0.488235                    0.031142
# 1                     0.520230                    0.025910
# 2                     0.469851                    0.046254
# 3                     0.496143                    0.044761
# 4                     0.491270                    0.013301
# 5                     0.532602                    0.013721
#
#    (metrics.roc-auc_l1_kld, mean)  (metrics.roc-auc_l1_kld, std)  \
# 0                        0.432196                       0.033163
# 1                        0.438290                       0.011086
# 2                        0.438182                       0.033515
# 3                        0.437494                       0.015946
# 4                        0.445892                       0.015724
# 5                        0.487797                       0.010889
#
#    (metrics.roc-auc_mse_top_k, mean)  (metrics.roc-auc_mse_top_k, std)  \
# 0                           0.438269                          0.017052
# 1                           0.428119                          0.012869
# 2                           0.439680                          0.024835
# 3                           0.470722                          0.012731
# 4                           0.472066                          0.010151
# 5                           0.480623                          0.009674
#
#    (metrics.roc-auc_mse_kld, mean)  (metrics.roc-auc_mse_kld, std)  \
# 0                         0.432190                        0.033135
# 1                         0.435849                        0.013203
# 2                         0.438178                        0.033490
# 3                         0.437554                        0.016058
# 4                         0.445899                        0.015787
# 5                         0.485587                        0.010463
#
#    (metrics.roc-auc_l1_top_k, mean)  (metrics.roc-auc_l1_top_k, std)  \
# 0                          0.438269                         0.017052
# 1                          0.428119                         0.012869
# 2                          0.439680                         0.024835
# 3                          0.470722                         0.012731
# 4                          0.472066                         0.010151
# 5                          0.480623                         0.009674
#
#    (metrics.roc-auc_mse, mean)  (metrics.roc-auc_mse, std)  \
# 0                     0.432151                    0.033076
# 1                     0.435117                    0.013975
# 2                     0.438137                    0.033452
# 3                     0.437759                    0.016311
# 4                     0.445974                    0.015792
# 5                     0.482800                    0.009075
#
#                                      params.pipeline params.data_source model
# 0  {'hist_equalisation': False, 'otsu_filter': Fa...            XR_HAND   vae
# 1  {'hist_equalisation': False, 'otsu_filter': Fa...  XR_HAND_PHOTOSHOP   vae
# 2  {'hist_equalisation': False, 'otsu_filter': Fa...    XR_HAND_CROPPED   vae
# 3  {'hist_equalisation': True, 'otsu_filter': Fal...    XR_HAND_CROPPED   vae
# 4  {'hist_equalisation': True, 'otsu_filter': Fal...            XR_HAND   vae
# 5  {'hist_equalisation': True, 'otsu_filter': Fal...  XR_HAND_PHOTOSHOP   vae

# %%
dcgan = mlflow.search_runs(experiment_ids=13)
grouped = dcgan.groupby(by='tags.mlflow.parentRunId').agg(['mean', 'std'])
dcgan = pd.merge(grouped, dcgan, left_on='tags.mlflow.parentRunId', right_on='run_id')
dcgan['model'] = 'dcgan'
summary['dcgan'] = (dcgan.filter(regex=r"\('metrics\.(roc-auc).+(mean|std)'\)|params.data_source|params.pipeline|model"))
summary['dcgan']
# Out:
#    (metrics.roc-auc_proba, mean)  (metrics.roc-auc_proba, std)  \
# 0                       0.493226                      0.015018
# 1                       0.496577                      0.017511
# 2                       0.530063                      0.027087
# 3                       0.527188                      0.022037
# 4                       0.490845                      0.040834
# 5                       0.492841                      0.024665
#
#                                      params.pipeline params.data_source  model
# 0  {'hist_equalisation': False, 'otsu_filter': Fa...    XR_HAND_CROPPED  dcgan
# 1  {'hist_equalisation': False, 'otsu_filter': Fa...            XR_HAND  dcgan
# 2  {'hist_equalisation': False, 'otsu_filter': Fa...  XR_HAND_PHOTOSHOP  dcgan
# 3  {'hist_equalisation': True, 'otsu_filter': Fal...  XR_HAND_PHOTOSHOP  dcgan
# 4  {'hist_equalisation': True, 'otsu_filter': Fal...            XR_HAND  dcgan
# 5  {'hist_equalisation': True, 'otsu_filter': Fal...    XR_HAND_CROPPED  dcgan

# %%
bigan = mlflow.search_runs(experiment_ids=14)
bigan = pd.merge(bigan.groupby(by='tags.mlflow.parentRunId').agg(['mean', 'std']), bigan, 
         left_on='tags.mlflow.parentRunId', right_on='run_id')
bigan['model'] = 'bigan'
summary['bigan'] = (bigan.filter(regex=r"\('metrics\.(roc-auc).+(mean|std)'\)|params.data_source|params.pipeline|model"))
summary['bigan']
# Out:
#    (metrics.roc-auc_proba, mean)  (metrics.roc-auc_proba, std)  \
# 0                       0.507926                      0.006761
# 1                       0.548873                      0.005502
# 2                       0.533833                      0.016119
# 3                       0.522525                      0.015852
#
#    (metrics.roc-auc_mse_top_k, mean)  (metrics.roc-auc_mse_top_k, std)  \
# 0                           0.470898                          0.011269
# 1                           0.475132                          0.033139
# 2                           0.459323                          0.029646
# 3                           0.480707                          0.034343
#
#    (metrics.roc-auc_mse, mean)  (metrics.roc-auc_mse, std)  \
# 0                     0.471333                    0.020670
# 1                     0.490527                    0.041768
# 2                     0.437937                    0.039306
# 3                     0.487518                    0.036769
#
#                                      params.pipeline params.data_source  model
# 0  {'hist_equalisation': False, 'otsu_filter': Fa...            XR_HAND  bigan
# 1  {'hist_equalisation': False, 'otsu_filter': Fa...  XR_HAND_PHOTOSHOP  bigan
# 2  {'hist_equalisation': False, 'otsu_filter': Fa...    XR_HAND_CROPPED  bigan
# 3  {'hist_equalisation': True, 'otsu_filter': Fal...  XR_HAND_PHOTOSHOP  bigan

# %%
alphagan = mlflow.search_runs(experiment_ids=15)
alphagan = pd.merge(alphagan.groupby(by='tags.mlflow.parentRunId').agg(['mean', 'std']), alphagan, 
         left_on='tags.mlflow.parentRunId', right_on='run_id')
alphagan['model'] = 'alphagan'
summary['alphagan'] = (alphagan.filter(regex=r"\('metrics\.(roc-auc).+(mean|std)'\)|params.data_source|params.pipeline|model"))
summary['alphagan']
# Out:
#    (metrics.roc-auc_proba_coproba, mean)  \
# 0                               0.534197
# 1                               0.503267
# 2                               0.607163
# 3                               0.583911
#
#    (metrics.roc-auc_proba_coproba, std)  (metrics.roc-auc_proba, mean)  \
# 0                              0.022009                       0.534213
# 1                              0.022215                       0.503266
# 2                              0.016476                       0.607163
# 3                              0.011626                       0.583904
#
#    (metrics.roc-auc_proba, std)  (metrics.roc-auc_mse_top_k, mean)  \
# 0                      0.022019                           0.445532
# 1                      0.022215                           0.464578
# 2                      0.016476                           0.421598
# 3                      0.011616                           0.532541
#
#    (metrics.roc-auc_mse_top_k, std)  (metrics.roc-auc_coproba, mean)  \
# 0                          0.017776                         0.499611
# 1                          0.030637                         0.500000
# 2                          0.016462                         0.500000
# 3                          0.013226                         0.500000
#
#    (metrics.roc-auc_coproba, std)  (metrics.roc-auc_mse, mean)  \
# 0                        0.000778                     0.466310
# 1                        0.000000                     0.475702
# 2                        0.000000                     0.441531
# 3                        0.000000                     0.528460
#
#    (metrics.roc-auc_mse, std)  \
# 0                    0.022034
# 1                    0.029384
# 2                    0.013056
# 3                    0.017742
#
#                                      params.pipeline params.data_source  \
# 0  {'hist_equalisation': False, 'otsu_filter': Fa...    XR_HAND_CROPPED
# 1  {'hist_equalisation': False, 'otsu_filter': Fa...            XR_HAND
# 2  {'hist_equalisation': False, 'otsu_filter': Fa...  XR_HAND_PHOTOSHOP
# 3  {'hist_equalisation': True, 'otsu_filter': Fal...  XR_HAND_PHOTOSHOP
#
#       model
# 0  alphagan
# 1  alphagan
# 2  alphagan
# 3  alphagan

# %%
summary_df = pd.concat(summary.values())
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
summary_df.to_csv('summary.csv')

# %%
summary_df['params.pipeline'] = summary_df['params.pipeline'].apply(eval).apply(lambda par: par['hist_equalisation'])

# %%
for col_mean, col_std in zip(summary_df.filter(regex=r"\('metrics\.(roc-auc).+(mean)'\)"),
                             summary_df.filter(regex=r"\('metrics\.(roc-auc).+(std)'\)")):
    rounding = lambda x: ('%.3f' % x)[1:]
    summary_df[col_mean[0]] = summary_df[col_mean].apply(rounding) + r' ± ' + summary_df[col_std].apply(rounding)

# %%
summary_df.drop(summary_df.filter(regex=r"\('metrics\.(roc-auc).+(mean|std)'").columns, axis=1, inplace=True)

# %%
df = summary_df.pivot_table(columns=['model', 'params.data_source', 'params.pipeline'], aggfunc='first')
df = df[~(df == r'an ± an')]
df = df.unstack(level=(2, 3)).reorder_levels((1, 0)).sort_index().sort_index(axis=1)

# %%
df[df.isna()] = '-'
df = df.reindex(['cae', 'vae', 'dcgan', 'bigan', 'alphagan'], level=0)
df = df.rename(index={'metrics.roc-auc_mse':'MSE', 
                 'metrics.roc-auc_mse_top_k': 'MSE (top-200)',
                 'metrics.roc-auc_kld': 'KLD',
                 'metrics.roc-auc_l1': 'L1', 
                 'metrics.roc-auc_l1_kld': 'L1 + KLD',
                 'metrics.roc-auc_l1_top_k': 'L1 (top-200)',
                 'metrics.roc-auc_mse_kld': 'MSE + KLD',
                 'metrics.roc-auc_proba': 'Discriminator (D)', 
                 'metrics.roc-auc_coproba': 'Code-Discriminator (C)',
                 'metrics.roc-auc_proba_coproba': 'C + D'}, level=1)
df = df.rename(columns={'XR_HAND':'raw', 
                        'XR_HAND_CROPPED': 'crop',
                        'XR_HAND_PHOTOSHOP': 'full'}, level=0)
df
# Out:
# params.data_source                       raw                      crop  \
# params.pipeline                        False        True         False
# model
# cae      MSE                     .460 ± .033  .504 ± .034  .466 ± .022
#          MSE (top-200)           .466 ± .013  .448 ± .025  .486 ± .015
# vae      KLD                     .488 ± .031  .491 ± .013  .470 ± .046
#          L1                      .432 ± .033  .446 ± .016  .438 ± .033
#          L1 + KLD                .432 ± .033  .446 ± .016  .438 ± .034
#          L1 (top-200)            .438 ± .017  .472 ± .010  .440 ± .025
#          MSE                     .432 ± .033  .446 ± .016  .438 ± .033
#          MSE + KLD               .432 ± .033  .446 ± .016  .438 ± .033
#          MSE (top-200)           .438 ± .017  .472 ± .010  .440 ± .025
# dcgan    Discriminator (D)       .497 ± .018  .491 ± .041  .493 ± .015
# bigan    MSE                     .471 ± .021            -  .438 ± .039
#          MSE (top-200)           .471 ± .011            -  .459 ± .030
#          Discriminator (D)       .508 ± .007            -  .534 ± .016
# alphagan Code-Discriminator (C)  .500 ± .000            -  .500 ± .001
#          MSE                     .476 ± .029            -  .466 ± .022
#          MSE (top-200)           .465 ± .031            -  .446 ± .018
#          Discriminator (D)       .503 ± .022            -  .534 ± .022
#          C + D                   .503 ± .022            -  .534 ± .022
#
# params.data_source                                   full
# params.pipeline                        True         False        True
# model
# cae      MSE                     .510 ± .021  .501 ± .013  .570 ± .019
#          MSE (top-200)           .473 ± .018  .506 ± .039  .553 ± .023
# vae      KLD                     .496 ± .045  .520 ± .026  .533 ± .014
#          L1                      .438 ± .016  .435 ± .014  .483 ± .009
#          L1 + KLD                .437 ± .016  .438 ± .011  .488 ± .011
#          L1 (top-200)            .471 ± .013  .428 ± .013  .481 ± .010
#          MSE                     .438 ± .016  .435 ± .014  .483 ± .009
#          MSE + KLD               .438 ± .016  .436 ± .013  .486 ± .010
#          MSE (top-200)           .471 ± .013  .428 ± .013  .481 ± .010
# dcgan    Discriminator (D)       .493 ± .025  .530 ± .027  .527 ± .022
# bigan    MSE                               -  .491 ± .042  .488 ± .037
#          MSE (top-200)                     -  .475 ± .033  .481 ± .034
#          Discriminator (D)                 -  .549 ± .006  .523 ± .016
# alphagan Code-Discriminator (C)            -  .500 ± .000  .500 ± .000
#          MSE                               -  .442 ± .013  .528 ± .018
#          MSE (top-200)                     -  .422 ± .016  .533 ± .013
#          Discriminator (D)                 -  .607 ± .016  .584 ± .012
#          C + D                             -  .607 ± .016  .584 ± .012

# %%
df_num = (df.applymap(lambda x: x[0:4]).applymap(lambda x: x if x!='-' else None).astype(float) - 0.50)

def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

df_num.style.apply(highlight_max, axis=1)
# Out:
# <style  type="text/css" >
#     #T_278358cc_0e22_11ea_805c_fa163e14c932row0_col5 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row1_col5 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row2_col5 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row3_col5 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row4_col5 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row5_col5 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row6_col5 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row7_col5 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row8_col5 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row9_col4 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row10_col4 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row11_col5 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row12_col4 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row13_col0 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row13_col2 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row13_col4 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row13_col5 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row14_col5 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row15_col5 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row16_col4 {
#             background-color:  yellow;
#         }    #T_278358cc_0e22_11ea_805c_fa163e14c932row17_col4 {
#             background-color:  yellow;
#         }</style><table id="T_278358cc_0e22_11ea_805c_fa163e14c932" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >params.data_source</th>        <th class="col_heading level0 col0" colspan=2>raw</th>        <th class="col_heading level0 col2" colspan=2>crop</th>        <th class="col_heading level0 col4" colspan=2>full</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >params.pipeline</th>        <th class="col_heading level1 col0" >False</th>        <th class="col_heading level1 col1" >True</th>        <th class="col_heading level1 col2" >False</th>        <th class="col_heading level1 col3" >True</th>        <th class="col_heading level1 col4" >False</th>        <th class="col_heading level1 col5" >True</th>    </tr>    <tr>        <th class="index_name level0" >model</th>        <th class="index_name level1" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_278358cc_0e22_11ea_805c_fa163e14c932level0_row0" class="row_heading level0 row0" rowspan=2>cae</th>
#                         <th id="T_278358cc_0e22_11ea_805c_fa163e14c932level1_row0" class="row_heading level1 row0" >MSE</th>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row0_col0" class="data row0 col0" >-0.04</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row0_col1" class="data row0 col1" >0.004</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row0_col2" class="data row0 col2" >-0.034</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row0_col3" class="data row0 col3" >0.01</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row0_col4" class="data row0 col4" >0.001</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row0_col5" class="data row0 col5" >0.07</td>
#             </tr>
#             <tr>
#                                 <th id="T_278358cc_0e22_11ea_805c_fa163e14c932level1_row1" class="row_heading level1 row1" >MSE (top-200)</th>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row1_col0" class="data row1 col0" >-0.034</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row1_col1" class="data row1 col1" >-0.052</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row1_col2" class="data row1 col2" >-0.014</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row1_col3" class="data row1 col3" >-0.027</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row1_col4" class="data row1 col4" >0.006</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row1_col5" class="data row1 col5" >0.053</td>
#             </tr>
#             <tr>
#                         <th id="T_278358cc_0e22_11ea_805c_fa163e14c932level0_row2" class="row_heading level0 row2" rowspan=7>vae</th>
#                         <th id="T_278358cc_0e22_11ea_805c_fa163e14c932level1_row2" class="row_heading level1 row2" >KLD</th>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row2_col0" class="data row2 col0" >-0.012</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row2_col1" class="data row2 col1" >-0.009</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row2_col2" class="data row2 col2" >-0.03</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row2_col3" class="data row2 col3" >-0.004</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row2_col4" class="data row2 col4" >0.02</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row2_col5" class="data row2 col5" >0.033</td>
#             </tr>
#             <tr>
#                                 <th id="T_278358cc_0e22_11ea_805c_fa163e14c932level1_row3" class="row_heading level1 row3" >L1</th>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row3_col0" class="data row3 col0" >-0.068</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row3_col1" class="data row3 col1" >-0.054</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row3_col2" class="data row3 col2" >-0.062</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row3_col3" class="data row3 col3" >-0.062</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row3_col4" class="data row3 col4" >-0.065</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row3_col5" class="data row3 col5" >-0.017</td>
#             </tr>
#             <tr>
#                                 <th id="T_278358cc_0e22_11ea_805c_fa163e14c932level1_row4" class="row_heading level1 row4" >L1 + KLD</th>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row4_col0" class="data row4 col0" >-0.068</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row4_col1" class="data row4 col1" >-0.054</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row4_col2" class="data row4 col2" >-0.062</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row4_col3" class="data row4 col3" >-0.063</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row4_col4" class="data row4 col4" >-0.062</td>
#                         <td id="T_278358cc_0e22_11ea_805c_fa163e14c932row4_col5" class="data row4 col5" >-0.012</td>
#             </tr>
#             <tr>
#                                 <th id="T_278358cc_0e22_1

# %%
print(df.to_latex(bold_rows=True))
# Out:
# \begin{tabular}{llllllll}
# \toprule
#          & \textbf{params.data\_source} & \multicolumn{2}{l}{raw} & \multicolumn{2}{l}{crop} & \multicolumn{2}{l}{full} \\
#          & \textbf{params.pipeline} &        False &        True  &        False &        True  &        False &        True  \\
# \textbf{model} & {} &              &              &              &              &              &              \\
# \midrule
# \textbf{cae} & \textbf{MSE} &  .460 ± .033 &  .504 ± .034 &  .466 ± .022 &  .510 ± .021 &  .501 ± .013 &  .570 ± .019 \\
#          & \textbf{MSE (top-200)} &  .466 ± .013 &  .448 ± .025 &  .486 ± .015 &  .473 ± .018 &  .506 ± .039 &  .553 ± .023 \\
# \textbf{vae} & \textbf{KLD} &  .488 ± .031 &  .491 ± .013 &  .470 ± .046 &  .496 ± .045 &  .520 ± .026 &  .533 ± .014 \\
#          & \textbf{L1} &  .432 ± .033 &  .446 ± .016 &  .438 ± .033 &  .438 ± .016 &  .435 ± .014 &  .483 ± .009 \\
#          & \textbf{L1 + KLD} &  .432 ± .033 &  .446 ± .016 &  .438 ± .034 &  .437 ± .016 &  .438 ± .011 &  .488 ± .011 \\
#          & \textbf{L1 (top-200)} &  .438 ± .017 &  .472 ± .010 &  .440 ± .025 &  .471 ± .013 &  .428 ± .013 &  .481 ± .010 \\
#          & \textbf{MSE} &  .432 ± .033 &  .446 ± .016 &  .438 ± .033 &  .438 ± .016 &  .435 ± .014 &  .483 ± .009 \\
#          & \textbf{MSE + KLD} &  .432 ± .033 &  .446 ± .016 &  .438 ± .033 &  .438 ± .016 &  .436 ± .013 &  .486 ± .010 \\
#          & \textbf{MSE (top-200)} &  .438 ± .017 &  .472 ± .010 &  .440 ± .025 &  .471 ± .013 &  .428 ± .013 &  .481 ± .010 \\
# \textbf{dcgan} & \textbf{Discriminator (D)} &  .497 ± .018 &  .491 ± .041 &  .493 ± .015 &  .493 ± .025 &  .530 ± .027 &  .527 ± .022 \\
# \textbf{bigan} & \textbf{MSE} &  .471 ± .021 &            - &  .438 ± .039 &            - &  .491 ± .042 &  .488 ± .037 \\
#          & \textbf{MSE (top-200)} &  .471 ± .011 &            - &  .459 ± .030 &            - &  .475 ± .033 &  .481 ± .034 \\
#          & \textbf{Discriminator (D)} &  .508 ± .007 &            - &  .534 ± .016 &            - &  .549 ± .006 &  .523 ± .016 \\
# \textbf{alphagan} & \textbf{Code-Discriminator (C)} &  .500 ± .000 &            - &  .500 ± .001 &            - &  .500 ± .000 &  .500 ± .000 \\
#          & \textbf{MSE} &  .476 ± .029 &            - &  .466 ± .022 &            - &  .442 ± .013 &  .528 ± .018 \\
#          & \textbf{MSE (top-200)} &  .465 ± .031 &            - &  .446 ± .018 &            - &  .422 ± .016 &  .533 ± .013 \\
#          & \textbf{Discriminator (D)} &  .503 ± .022 &            - &  .534 ± .022 &            - &  .607 ± .016 &  .584 ± .012 \\
#          & \textbf{C + D} &  .503 ± .022 &            - &  .534 ± .022 &            - &  .607 ± .016 &  .584 ± .012 \\
# \bottomrule
# \end{tabular}
