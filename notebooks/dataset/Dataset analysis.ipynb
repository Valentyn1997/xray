# %%
from IPython.display import Image

# %% [markdown]
# 1. Different contrast levels/colors

# %%
Image("../../data/train/XR_HAND/patient00218/study1_positive/image1.png")

# %%
Image("../../data/train/XR_HAND/patient00218/study2_negative/image3.png")

# %% [markdown]
# 2. Not all hand in a picture

# %%
Image("../../data/train/XR_HAND/patient00457/study1_negative/image3.png")

# %% [markdown]
# 3. Different odd objects

# %%
Image("../../data/train/XR_HAND/patient00483/study1_negative/image1.png")

# %% [markdown]
# 4. Quality of images is different

# %%
Image("../../data/train/XR_HAND/patient00485/study1_negative/image3.png")

# %% [markdown]
# Angles are different

# %%
Image("../../data/train/XR_HAND/patient00565/study1_negative/image1.png")

# %% [markdown]
# Double hands

# %%
Image("../../data/train/XR_HAND/patient00588/study1_positive/image1.png")

# %% [markdown]
# For the same view point positions are different

# %%
Image("../../data/train/XR_HAND/patient00604/study1_negative/image3.png")

# %%
Image("../../data/train/XR_HAND/patient00608/study1_negative/image1.png")

# %%
Image("../../data/train/XR_HAND/patient00648/study1_negative/image2.png")
